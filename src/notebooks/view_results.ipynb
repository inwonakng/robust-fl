# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
no_straggle = pd.read_csv('../output/MNIST_MLP_FedAvg/no_straggle/report.csv')
yes_straggle = pd.read_csv('../output/MNIST_MLP_FedAvg/5_straggle/report.csv')

# %%
no_straggle
# Out:
#       Unnamed: 0  round  client_req  new_updates  \
# 0              0      0          10           10
# 1              1      1          10           10
# 2              2      2          10           10
# 3              3      3          10           10
# 4              4      4          10           10
# ...          ...    ...         ...          ...
# 1995        1995   1995          10           10
# 1996        1996   1996          10           10
# 1997        1997   1997          10           10
# 1998        1998   1998          10           10
# 1999        1999   1999          10           10
#
#                                                avg_loss  queue_size  \
# 0     [13.943954610824585, 14.185199403762818, 14.58...           0
# 1     [13.656962013244629, 13.650846147537232, 13.59...           0
# 2     [13.373305749893188, 13.285975742340089, 13.75...           0
# 3     [13.297877979278564, 13.282827663421632, 13.41...           0
# ...

# %%
no_straggle.accuracy_score.plot()
# Out:
# <Axes: >

# %%
yes_straggle.accuracy_score.plot()
# Out:
# <Axes: >
